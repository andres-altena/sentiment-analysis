# %%
#import NLP
import spacy
import nltk
from nltk.tokenize import word_tokenize
import gensim

import string

import pandas as pd
from pathlib import *
import json
import os
from os.path import isfile, join
from datetime import datetime

# %%
nlp = spacy.load('en_core_web_sm')

# %%
#Load the dataframe
path_to_df = Path("..") / "data" / "processed" / "initial_df.csv"
messages_df = pd.read_csv(path_to_df)
#Filter only my messages, only messaged of type "Generic" (ie no calls, shares...) and remove NA
andres_df = messages_df[messages_df["Sender"] == "Andres Altena"].reset_index(drop = True)
andres_df.dropna(inplace = True)
andres_df = andres_df[andres_df["type"] == "Generic"].reset_index(drop = True)
andres_df["Preprocessed"] = andres_df["Message"].apply(lambda x: gensim.utils.simple_preprocess(x))

# %%
path_to_untagged = Path("..") / "data" / "processed" / "untagged_data.xlsx"
path_to_untagged

# %%
andres_df.to_excel(path_to_untagged)

# %%
andres_df
# Out:
#                                           Title       IsGroup  StillPart  \
# 0                        10 degrees? Dangerous?  RegularGroup       True
# 1                        10 degrees? Dangerous?  RegularGroup       True
# 2                        10 degrees? Dangerous?  RegularGroup       True
# 3                        10 degrees? Dangerous?  RegularGroup       True
# 4                        10 degrees? Dangerous?  RegularGroup       True
# 5                        10 degrees? Dangerous?  RegularGroup       True
# 6                        10 degrees? Dangerous?  RegularGroup       True
# 7                        10 degrees? Dangerous?  RegularGroup       True
# 8                        10 degrees? Dangerous?  RegularGroup       True
# 9                        10 degrees? Dangerous?  RegularGroup       True
# 10                       10 degrees? Dangerous?  RegularGroup       True
# 11                       10 degrees? Dangerous?  RegularGroup       True
# 12                       10 degrees? Dangerous?  RegularGroup       True
# 13                       10 degrees? Dangerous?  RegularGroup       True
# 14                       10 degrees? Dangerous?  RegularGroup       True
# 15                       10 degrees? Dangerous?  RegularGroup       True
# 16                       10 degrees? Dangerous?  RegularGroup       True
# 17                       10 degrees? Dangerous?  RegularGroup       True
# 18                       10 degrees? Dangerous?  RegularGroup       True
# 19                       10 degrees? Dangerous?  RegularGroup       True
# 20                       10 degrees? Dangerous?  RegularGroup       True
# 21                       10 degrees? Dangerous?  RegularGroup       True
# 22                       10 degrees? Dangerous?  RegularGroup       True
# 23                       10 degrees? Dangerous?  RegularGroup       True
# 24                       10 degrees? Dangerous?  RegularGroup       True
# 25                       10 degrees? Dangerous?  RegularGroup       True
# 26                       10 degrees? Dangerous?  RegularGroup       True
# 27     Abandonment Issues but like fr this time  RegularGroup      False
# 28     Abandonment Issues but like fr this time  RegularGroup      False
# 29     Abandonment Issues but like fr this time  RegularGroup      False
# ...                                         ...           ...        ...
# 59735                                Yuhang Xie       Regular       True
# 59736                                Yuhang Xie       Regular       True
# 59737                                Yuhang Xie       Regular       True
# 59738                                 Zack Case       Regular       True
# 59739                                 Zack Case       Regular       True
# 59740                                 Zack Case       Regular       True
# 59741                                 Zack Case       Regular       True
# 59742                                 Zack Case       Regular       True
# 59743                                 Zack Case       Regular       True
# 59744                                 Zack Case       Regular       True
# 59745                                 Zack Case       Regular       True
# 59746                                 Zack Case       Regular       True
# 59747                                 Zack Case       Regular       True
# 59748                                 Zack Case       Regular       True
# 59749                                 Zack Case       Regular       True
# 59750                                 Zack Case       Regular       True
# 59751                                 Zack Case       Regular       True
# 59752                                 Zack Case       Regular       True
# 59753                             Zakir Khokher       Regular       True
# 59754                             Zakir Khokher       Regular       True
# 59755                             Zakir Khokher       Regular       True
# 59756                             Zakir Khokher       Regular       True
# 59757                             Zakir Khokher       Regular       True
# 59758                             Zakir Khokher       Regular       True
# 59759                             Zakir Khokher       Regular       True
# 59760                             Zakir Khokher       Regular       True
# 59761                                     Zesty  RegularGroup       True
# 59762                                     Zesty  RegularGroup       True
# 59763                          Zornitsa Zheleva       Regular       True
# 59764                          Zornitsa Zheleva       Regular       True
#
#        NumParticipants                                       Participants  \
# 0                    4  Andres Altena,James Roberts,Jamie Blaiklock,Fr...
# 1                    4  Andres Altena,James Roberts,Jamie Blaiklock,Fr...
# 2                    4  Andres Altena,James Roberts,Jamie Blaiklock,Fr...
# 3                    4  Andres Altena,James Roberts,Jamie Blaiklock,Fr...
# 4                    4  Andres Altena,James Roberts,Jamie Blaiklock,Fr...
# 5                    4  Andres Altena,James Roberts,Jamie Blaiklock,Fr...
# 6                    4  Andres Altena,James Roberts,Jamie Blaiklock,Fr...
# 7                    4  Andres Altena,James Roberts,Jamie Blaiklock,Fr...
# 8                    4  Andres Altena,James Roberts,Jamie Blaiklock,Fr...
# 9                    4  Andres Altena,James Roberts,Jamie Blaiklock,Fr...
# 10                   4  Andres Altena,James Roberts,Jamie Blaiklock,Fr...
# 11                   4  Andres Altena,James Roberts,Jamie Blaiklock,Fr...
# 12                   4  Andres Altena,James Roberts,Jamie Blaiklock,Fr...
# 13                   4  Andres Altena,James Roberts,Jamie Blaiklock,Fr...
# 14                   4  Andres Altena,James Roberts,Jamie Blaiklock,Fr...
# 15                   4  Andres Altena,James Roberts,Jamie Blaiklock,Fr...
# 16                   4  Andres Altena,James Roberts,Jamie Blaiklock,Fr...
# 17                   4  Andres Altena,James Roberts,Jamie Blaiklock,Fr...
# 18                   4  Andres Altena,James Roberts,Jamie Blaiklock,Fr...
# 19                   4  Andres Altena,James Roberts,Jamie Blaiklock,Fr...
# 20                   4  Andres Altena,James Roberts,Jamie Blaiklock,Fr...
# 21                   4  Andres Altena,James Roberts,Jamie Blaiklock,Fr...
# 22                   4  Andres Altena,James Roberts,Jamie Blaiklock,Fr...
# 23                   4  Andres Altena,James Roberts,Jamie Blaiklock,Fr...
# 24                   4  Andres Altena,James Roberts,Jamie Blaiklock,Fr...
# 25                   4  Andres Altena,James Roberts,Jamie Blaiklock,Fr...
# 26                   4  Andres Altena,James Roberts,Jamie Blaiklock,Fr...
# 27                   9  Shail Desai,Eleanor King,Preben Monteiro Ness,...
# 28                   9  Shail Desai,Eleanor King,Preben Monteiro Ness,...
# 29                   9  Shail Desai,Eleanor King,Preben Monteiro Ness,...
# ...                ...                                                ...
# 59735                2                           Yuhang Xie,Andres Altena
# 59736                2                           Yuhang Xie,Andres Altena
# 59737                2                           Yuhang Xie,Andres Altena
# 59738                2                            Zack Case,Andres Altena
# 59739                2                            Zack Case,Andres Altena
# 59740                2                            Zack Case,Andres Altena
# 59741                2                            Zack Case,Andres Altena
# 59742                2                            Zack Case,Andres Altena
# 59743                2                            Zack Case,Andres Altena
# 59744                2                            Zack Case,Andres Altena
# 59745                2                            Zack Case,Andres Altena
# 59746                2                            Zack Case,Andres Altena
# 59747                2                            Zack Case,Andres Altena
# 59748                2                            Zack Case,Andres Altena
# 59749                2                            Zack Case,Andres Altena
# 59750                2                            Zack Case,Andres Altena
# 59751                2                            Zack Case,Andres Altena
# 59752                2                            Zack Case,Andres Altena
# 59753                2                        Zakir Khokher,Andres Altena
# 59754                2                        Zakir Khokher,Andres Altena
# 59755                2                        Zakir Khokher,Andres Altena
# 59756                2                        Zakir Khokher,Andres Altena
# 59757                2                        Zakir Khokher,Andres Altena
# 59758                2                        Zakir Khokher,Andres Altena
# 59759                2                        Zakir Khokher,Andres Altena
# 59760                2                        Zakir Khokher,Andres Altena
# 59761               21  Abdulla Qmsz,Shail Desai,Andres Altena,James R...
# 59762               21  Abdulla Qmsz,Shail Desai,Andres Altena,James R...
# 59763                2                     Zornitsa Zheleva,Andres Altena
# 59764                2                     Zornitsa Zheleva,Andres Altena
#
#               Sender                                            Message  \
# 0      Andres Altena                                                â
# 1      Andres Altena  Also we should include a picture with low angl...
# 2      Andres Altena                              Just as a rough guide
# 3      Andres Altena           Then control surfaces done by the last 2
# 4      Andres Altena  Then second person talks about Yaw and varying...
# 5      Andres Altena                         And that could be 4-5 mind
# 6      Andres Altena                                Talk about vortex 2
# 24                               [do, we, need, to, yaw]
# 25     [photos, per, angle, of, attack, angles, of, a...
# 26                                                    []
# 27                  [and, then, we, ll, see, you, there]
# 28     [we, re, moving, shails, bike, to, the, bike, ...
# 29                     [alright, prebs, all, moved, out]
# ...                                                  ...
# 59735                                      [no, worries]
# 59736           [ah, no, worries, then, thanks, anyways]
# 59737  [hey, yuhang, sheamol, told, me, you, ve, got,...
# 59738              [that, brilliant, ll, see, you, soon]
# 59739  [problem, is, that, they, leave, during, the, ...
# 59740       [could, play, if, necessary, to, be, honest]
# 59741  [hey, zack, ve, got, couple, friends, over, fr...
# 59742  [hey, don, think, should, play, today, unless,...
# 59743  [ve, got, supervision, on, wednesday, at, pm, ...
# 59744                                               [ok]
# 59745  [ve, got, the, receipt, from, the, taxi, when,...
# 59746                              [account, number, is]
# 59747                                   [sort, code, is]
# 59748  [what, do, you, need, sort, code, and, account...
# 59749                                               [ok]
# 59750  [won, make, it, to, training, but, are, you, g...
# 59751                                      [no, worries]
# 59752  [hey, could, you, bring, the, pounds, to, trai...
# 59753                              [induction, training]
# 59754                           [meet, at, the, porters]
# 59755                [during, freshers, at, some, point]
# 59756                      [we, dont, really, know, yet]
# 59757  [think, shail, already, told, you, about, the,...
# 59758                               [whats, your, crsid]
# 59759                                        [hey, mate]
# 59760                         [ill, be, there, in, mins]
# 59761             [this, still, happening, in, the, bar]
# 59762                                                 []
# 59763                            [what, happened, there]
# 59764                                       [excuse, me]
#
# [59765 rows x 10 columns]

# %% [markdown]
# # THE FOLLOWING FUNCTIONS ARE NOT CURRENTLY IN USE

# %%
def remove_punct(token_text, punct):    
    text = [word for word in token_text if word not in punct]
    return text

# %%
def make_lowercase(text):
    text = text.lower()
    return text

# %%
def remove_stopwords(token_text, stopwords):
    #This function is fed the tokenised text and will remove all the words which are
    #stopwords
    text = [word for word in token_text if word not in stopwords]
    return text

# %%
def tokenise_messages(df):   
    df["Message_token"] = [word_tokenize(doc) for doc in df["lowercase"]] 
    return df

# %%
def basic_preprocessing(df):
    #################################################
    ###### THIS IS NOT BEING USED ###################
    #################################################
    
    
    
    #This function will do the basic preprocessing of the tokenised messaged
    
    #1 - Make all lowercase
    df["lowercase"] = df["Message"].apply(lambda x: make_lowercase(x))
    
    #2 - Tokenise and add the tokenise column
    tokenise_messages(df);
    
    #3 - Remove stopwords - at the moment we use nltk basic list of stopwords
    stopwords = nltk.corpus.stopwords.words("english")
    further_stopwords = []
    stopwords.append(further_stopwords)
    stopwords_to_keep = []
    [stopwords.remove(x) for x in stopwords_to_keep]
    #Remove the stopwords:
    df["Preprocessed"] = df["Message_token"].apply(lambda x: remove_stopwords(x, stopwords))
    
    #4 - Remove punctuation
    #use punctuation from string library
    punct = string.punctuation
    punct_to_keep = []
    [punct.remove(x) for x in punct_to_keep]
    df["Preprocessed"] = df["Preprocessed"].apply(lambda x: remove_punct(x, punct))
    
    #5 - Remove numbers?
    
    #Drop the lowercase column
    df.drop(["lowercase"], axis = 1)
    
    return df
